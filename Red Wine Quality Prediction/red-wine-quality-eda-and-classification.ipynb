# %%
import skimpy
import pandas as pd

# %%
df = pd.read_csv("winequality-red.csv")
report = skimpy.skim(df)

print(report)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 1599   │ │ float64     │ 11    │                                                          │
# │ │ Number of columns │ 12     │ │ int32       │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# ...

# %% [markdown]
# <img src="https://i.imgur.com/BgsBICA.png" style="width:100%">

# %% [markdown]
# <div style="font-size:15px; text-align:justify">
# <p>This notebook is using the <em><strong>Red Wine Quality Dataset</strong></em> from the UCI MACHINE LEARNING in which the two datasets are related to red and white variants of the Portuguese "Vinho Verde" wine. For more details, consult the reference [Cortez et al., 2009]. Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).</p>
#
# <p>In this notebook we will do <em><strong>Exploratory Data Analysis</strong></em> then <em><strong>Classification</strong></em> with some <em><strong>Prediction</strong></em> of the Quality of Red Wine.</p>
#
# </div>

# %% [markdown]
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">table of contents</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>
#
# <br><br>
#
# 1. [Data Exploration](#dataA)
# 2. [Feature Enginnering](#dataB)<br>
#     2.1. [Lets scale the Wine](#dataC)<br>
#     2.2. [Sampling the Data](#dataD)<br>
# 3. [Data Visualisations](#dataE1)<br>
#     3.1. [Visualize the fixed acidity contents in red wine](#dataF)<br>
#     3.2. [Visualize the volatile acidity contents in red wine](#dataG)<br>
#     3.3. [Visualize the citric acid contents in red wine](#dataH)<br>
#     3.4. [Visualize the residual sugar contents in red wine](#dataI)<br>
#     3.5. [Visualize the chlorides contents in red wine](#dataJ)<br>
#     3.6. [Visualize the free sulfur dioxide contents in red wine](#dataK)<br>
#     3.7. [Visualize the total sulfur dioxide contents in red wine](#dataL)<br>
#     3.8. [Visualize the density contents in red wine](#dataM)<br>
#     3.9. [Visualize the pH contents in red wine](#dataN)<br>
#     3.10. [Visualize the sulphates contents in red wine](#dataO)<br>
#     3.11. [Visualize the alcohol contents in red wine](#dataP)<br>
#     3.12. [Visualize the Correlation contents in red wine](#dataQ)<br>
#     3.13. [Visualize the Relationships between variables contents in red wine](#dataS)<br>
# 4. [Preprocessing](#dataX)<br>
#     4.1. [Feature Scaling](#dataY)<br>
#     4.2. [Train, test split](#dataZ)<br>
# 5. [Models](#dataAA)<br>
#     5.1. [Decision Tree](#dataBB)<br>
#     5.2. [Random Forest](#dataCC)<br>
#     5.3. [Cross Validation Score](#dataDD)<br>
#     5.3.a. [Logistic Regression Cross Validation Accuracy score](#dataEE)<br>
#     5.3.b. [Decision Tree Classifier Cross Validation Accuracy score](#dataFF)<br>
#     5.3.c. [Random Forest Classifier Cross Validation Accuracy score](#dataHH)<br>
#     5.3.d. [Xgboost Classifier Cross Validation Accuracy score](#dataGG)<br>
#     5.3.e. [Model Scores using Cross Validation score](#dataKK)<br>
#     5.4. [Voting Classifier](#dataLL)<br>
# 6. [Conclusion](#dataQQ)
#
# <p style="text-align:center"><img src="https://i.imgur.com/ugj24t1.png" style="width:30%"></p>
#
# <br>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
#import squarify

palette = sns.color_palette("Spectral")


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <a id="dataA"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">1. Data Exploration</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
df = pd.read_csv('winequality-red.csv')

# %%
df.head(10).style.set_properties(**{'background-color': '#F6FBFC','color': '#000','border': '1px solid #000000'})
# Out:
# <style type="text/css">
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# <a id="dataB"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">2. Feature Enginnering</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>
#
# 2.1. Lets scale the Wine
#
# 2.2. Sampling the Data

# %% [markdown]
# <a id="dataC"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">2. 1. Lets scale the Wine</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>
#
# So, after reading the Red Wine Quality dataset description we got that;
#
# quality > 6.5 is "good"
# quality < 6.5 is "bad"
#
# good --> 1
# bad ---> 0

# %%
df['quality'] = df['quality'].apply(lambda x: 1 if x > 6.5 else 0)

# %%
df['quality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %%
sns.set_style("white")
plt.figure(figsize=(15, 4))

wineScale_insight = df['quality']

plt.subplot(1, 2, 1)
sns.countplot(data=df, x=wineScale_insight)
plt.xticks([0,1], ['bad wine', 'good wine'])
plt.xlabel("\nTypes of Wine")


plt.subplot(1, 2, 2)
plt.pie(wineScale_insight.value_counts().values, labels=['bad wine', 'good wine'], autopct="%.2f%%", explode=[0.1, 0], colors=palette)
plt.xlabel("\nPercentage of Wine")

plt.suptitle('Different categories of Wines')
sns.despine()

# %% [markdown]
# <a id="dataD"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">2. 2. Sampling the Data</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>
#
# So from the above visualization we can see that the Dataset is skewed or unbalanced, now what we can do is to Over Sample the minority class using Synthetic Minority Oversampling Technique (SMOTE)

# %%
X = df.drop(['quality'], axis=1)
y = df.quality

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_smote, y_smote = smote.fit_resample(X, y)

# %%
sns.set_style("white")
plt.figure(figsize=(15, 4))

plt.subplot(1, 2, 1)
sns.countplot(data=df, x='quality')
plt.xticks([0,1], ['bad wine', 'good wine'])
plt.xlabel("\nBefore sampling")

plt.subplot(1, 2, 2)
sns.countplot(x=y_smote, palette=palette)
plt.xticks([0,1], ['bad wine', 'good wine'])
plt.xlabel("\nAfter sampling")

plt.suptitle('Over sampling \n\n\n')

sns.despine()

# %% [markdown]
# <a id="dataE1"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">3. Data Visualizations</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
def viz_insights(field):
    plt.figure(figsize=(15, 5))
    sns.histplot(data=df, x=field, hue="quality", kde=True, bins=20, multiple="stack", alpha=.3)
    plt.legend(['bad wine', 'good wine'])
    
    if field == "density":
        plt.title(f"\n{field.capitalize()} of red wine\n\n")
    else:
        plt.title(f"\n{field} contents in red wine\n\n")
    
    plt.figtext(0.75, 0.3, f'{df[field].describe()}')
    sns.despine()

# %% [markdown]
# <a id="dataF"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">3.1. Visualize the fixed acidity contents in red wine</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
viz_insights("fixed acidity")

# %% [markdown]
# <a id="dataG"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">3.2. Visualize the volatile acidity contents in red wine</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
viz_insights("volatile acidity")

# %% [markdown]
# <a id="dataH"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">3.3. Visualize the citric acid contents in red wine</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
viz_insights("citric acid")

# %% [markdown]
# <a id="dataI"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">3.4. Visualize the residual sugar contents in red wine</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
viz_insights("residual sugar")

# %% [markdown]
# <a id="dataJ"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">3.5. Visualize the chlorides contents in red wine </em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
viz_insights("chlorides")

# %% [markdown]
# <a id="dataK"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">3.6. Visualize the free sulfur dioxide contents in red wine</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
viz_insights("free sulfur dioxide")

# %% [markdown]
# <a id="dataL"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">3.7. Visualize the total sulfur dioxide contents in red wine </em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
viz_insights("total sulfur dioxide")

# %% [markdown]
# <a id="dataM"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">3. 8. Visualize the density contents in red wine</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
viz_insights("density")

# %% [markdown]
# <a id="dataN"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">3. 9. Visualize the pH contents in red wine</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
viz_insights("pH")

# %% [markdown]
# <a id="dataO"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">3. 10. Visualize the sulphates contents in red wine</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
viz_insights("sulphates")

# %% [markdown]
# <a id="dataP"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">3. 11. Visualize the alcohol contents in red wine </em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
viz_insights("alcohol")

# %% [markdown]
# <a id="dataQ"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">3. 12. Visualize the Correlation contents in red wine</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
df.corr().style.background_gradient(cmap=plt.cm.Spectral)
# Out:
# <style type="text/css">
# #T_61bef_row0_col0, #T_61bef_row1_col1, #T_61bef_row2_col2, #T_61bef_row3_col3, #T_61bef_row4_col4, #T_61bef_row5_col5, #T_61bef_row6_col6, #T_61bef_row7_col7, #T_61bef_row8_col8, #T_61bef_row9_col9, #T_61bef_row10_col10, #T_61bef_row11_col11 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_61bef_row0_col1, #T_61bef_row9_col1 {
#   background-color: #f06744;
#   color: #f1f1f1;
# }
# #T_61bef_row0_col2 {
#   background-color: #6ec5a5;
#   color: #000000;
# }
# #T_61bef_row0_col3, #T_61bef_row4_col10 {
#   background-color: #ef6645;
#   color: #f1f1f1;
# }
# #T_61bef_row0_col4 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_61bef_row0_col5, #T_61bef_row0_col8, #T_61bef_row1_col2, #T_61bef_row1_col9, #T_61bef_row1_col11, #T_61bef_row2_col1, #T_61bef_row7_col10, #T_61bef_row8_col0, #T_61bef_row8_col3, #T_61bef_row8_col4, #T_61bef_row10_col6, #T_61bef_row10_col7 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# ...

# %%
plt.figure(figsize=(13, 10))
sns.heatmap(df.corr(), annot=True, cmap=plt.cm.Spectral)
plt.show()

# %% [markdown]
# <a id="dataS"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">3.13.Relationships between variables contents in red wine</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
sns.pairplot(df, hue='quality', size=1.2, diag_kind = 'kde')
plt.show()

# %% [markdown]
# <a id="dataX"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">4. Preprocessing</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %% [markdown]
# <a id="dataY"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">4. 1. Feature Scaling</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>
#
#
#
# Lets scale the variables in range

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X_smote)

# %% [markdown]
# <a id="dataZ"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">4. 2. Train, test split </em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>
#
#
#
# Lets split it into Train and test variable

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size=0.25, random_state=42)

# %% [markdown]
# <a id="dataAA"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">5. Models</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>
#
#
# 5.1. Decision Tree
#
# 5.2. Random Forest
#
# 5.3. Cross Validation Score
#
# 5.3.a. Logistic Regression Cross Validation Accuracy score
#
# 5.3.b. Decision Tree Classifier Cross Validation Accuracy score
#
# 5.3.c. Random Forest Classifier Cross Validation Accuracy score
#
# 5.3.d. Xgboost Classifier Cross Validation Accuracy score
#
# 5.3.e. Model Scores using Cross Validation score
#
# 5.4. Voting Classifier

# %% [markdown]
# <a id="dataBB"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">5. 1. Decision Tree</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
from sklearn.tree import DecisionTreeClassifier
DT_classifer = DecisionTreeClassifier()
DT_classifer.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
DT_y_pred = DT_classifer.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print('Model accuracy score with criterion entropy: {:0.2%}'. format(accuracy_score(y_test, DT_y_pred)))
# Out:
# Model accuracy score with criterion entropy: 89.15%

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, DT_y_pred)

# %%
label = ['True Positives', 'False Negatives', 'False Positives', 'True Negatives']
annot = np.array([[f'{i}\n\n{j}' for i, j in zip(row, label)] for row in cm])
status = ['bad wine[0]', 'good wine[1]']


ax = sns.heatmap(cm, annot=annot, fmt='', linecolor='white', linewidths=10 ,cmap="cividis" ,
                 xticklabels=status, yticklabels=status )
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# <a id="dataCC"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">5. 2. Random Forest</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rf_y_pred = rf_classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# acc = format(accuracy_score(y_test, y_pred)
print('Model accuracy score with criterion entropy: {:0.2%}'. format(accuracy_score(y_test, rf_y_pred)))
# Out:
# Model accuracy score with criterion entropy: 93.34%

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, rf_y_pred)

# %%
label = ['True Positives', 'False Negatives', 'False Positives', 'True Negatives']
annot = np.array([[f'{i}\n\n{j}' for i, j in zip(row, label)] for row in cm])
status = ['bad wine[0]', 'good wine[1]']


ax = sns.heatmap(cm, annot=annot, fmt='', linecolor='white', linewidths=10 ,cmap="cividis" ,
                 xticklabels=status, yticklabels=status )
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from lazypredict.Supervised import LazyClassifier

clf = LazyClassifier(verbose=0 , ignore_warnings=True , custom_metric=None)

models , predictions = clf.fit(X_train, X_test, y_train, y_test)


pd.DataFrame(models)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:04<00:00,  6.12it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.95               0.95     0.95      0.95
# XGBClassifier                      0.95               0.95     0.95      0.95
# LGBMClassifier                     0.94               0.94     0.94      0.94
# RandomForestClassifier             0.93               0.94     0.94      0.93
# BaggingClassifier                  0.92               0.92     0.92      0.92
# LabelPropagation                   0.92               0.92     0.92      0.92
# LabelSpreading                     0.92               0.92     0.92      0.92
# DecisionTreeClassifier             0.91               0.91     0.91      0.91
# SVC                                0.90               0.90     0.90      0.90
# ...

# %% [markdown]
# <a id="dataDD"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">5. 3. Cross Validation Score</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
from sklearn.model_selection import cross_val_score
model_names, cv_scores = [], []

# %% [markdown]
# <a id="dataEE"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">5.3.a. Logistic Regression Cross Validation Accuracy score</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter = 2000)
cv = cross_val_score(lr,X_train,y_train,cv=5)

model_names.append("Logistic Regression")
cv_scores.append(str(round(cv.mean()*100, 2)) + " %")
print('Logistic Regression Cross Validation Accuracy score: {:0.2%}'. format(cv.mean()))
# Out:
# Logistic Regression Cross Validation Accuracy score: 81.09%

# %% [markdown]
# <a id="dataFF">
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">5.3.b. Decision Tree Classifier Cross Validation Accuracy</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
dt = DecisionTreeClassifier(random_state = 1)
cv = cross_val_score(dt,X_train,y_train,cv=5)
model_names.append("Decision Tree Classifier")
cv_scores.append(str(round(cv.mean()*100, 2)) + " %")
print('Decision Tree Classifier Cross Validation Accuracy score: {:0.2%}'. format(cv.mean()))
# Out:
# Decision Tree Classifier Cross Validation Accuracy score: 88.08%

# %% [markdown]
# <a id="dataHH"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: lawercase; letter-spacing: 2px;">5.3.c. Random Forest Classifier Cross Validation Accuracy</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
rf = RandomForestClassifier(random_state = 1)
cv = cross_val_score(rf,X_train,y_train,cv=5)
model_names.append("Random Forest Classifier")
cv_scores.append(str(round(cv.mean()*100, 2)) + " %")
print('Random Forest Classifier Cross Validation Accuracy score: {:0.2%}'. format(cv.mean()))
# Out:
# Random Forest Classifier Cross Validation Accuracy score: 93.20%

# %% [markdown]
# <a id="dataGG"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">5. 3. d. Xgboost Classifier Cross Validation Accuracy score</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(random_state =1)
cv = cross_val_score(xgb,X_train,y_train,cv=5)
model_names.append("Xgboost Classifier")
cv_scores.append(str(round(cv.mean()*100, 2)) + " %")
print('xgboost Classifier Cross Validation Accuracy score: {:0.2%}'. format(cv.mean()))
# Out:
# xgboost Classifier Cross Validation Accuracy score: 93.92%

# %% [markdown]
# <a id="dataKK"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">5.3.e. Model Scores using Cross Validation score</em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
model_names, cv_scores

model_acc_cv_df = pd.DataFrame(list(zip(model_names,cv_scores)), columns=["Model", "CV Score"])
model_acc_cv_df.index = np.arange(1, len(model_acc_cv_df)+1)
model_acc_cv_df
# Out:
#                       Model CV Score
# 1       Logistic Regression  81.09 %
# 2  Decision Tree Classifier  88.08 %
# 3  Random Forest Classifier   93.2 %
# 4        Xgboost Classifier  93.92 %

# %% [markdown]
# <a id="dataLL"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">5. 4. Voting Classifier </em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %%
from sklearn.ensemble import VotingClassifier
voting_clf = VotingClassifier(estimators = [('lr',lr), ('dt',dt), ('rf',rf), ('xgb',xgb)], voting = 'soft')

# %%
voting_clf
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression(max_iter=2000)),
#                              ('dt', DecisionTreeClassifier(random_state=1)),
#                              ('rf', RandomForestClassifier(random_state=1)),
#                              ('xgb',
#                               XGBClassifier(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=None,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval...
#                                             gpu_id=None, grow_policy=None,
#                                             importance_type=None,
# ...

# %%
cv = cross_val_score(voting_clf, X_train, y_train, cv=5)
print('Voting Classifier Cross Validation Accuracy score: {:0.2%}'. format(cv.mean()))
# Out:
# Voting Classifier Cross Validation Accuracy score: 91.75%

# %% [markdown]
# <a id="dataQQ"></a>
# <div style="background:url(https://www.cwservices.co.za/wp-content/uploads/2017/10/CSS-footer-bg.jpg) no-repeat; background-size:cover; width:100%; height:80px; padding:20px 0; border-radius: 20px; position: relative; overflow: hidden;">
#   <h3 style="font-family: 'Jura', sans-serif !important; color: white; font-size: 24px; margin: 0; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <em style="font-style: italic; text-transform: uppercase; letter-spacing: 2px;">6. Conclusion </em>
#   </h3>
#   <div style="position: absolute; top: -20px; right: -20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 20px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
#   <div style="position: absolute; top: -20px; right: 60px; width: 100px; height: 100px; background-color: #888888; transform: rotate(-45deg);"></div>
# </div>

# %% [markdown]
# <p style="text-align:center"><img src="https://media.tenor.com/qN0okW9otKoAAAAj/thank-you-sticker-thanks-sticker.gif"></p>
# <br><br>
# <p style="text-align:center; font-weight:600; font-size:18px"><em>Thank you! For viewing this Notebook, Please feel free to provide any feedback!… </em>😄<br>
# <img src="https://i.imgur.com/ugj24t1.png" style="width:30%">
# </p>
#
# <br><br>
